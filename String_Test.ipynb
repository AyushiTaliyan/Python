# %%
string1 = "Python is a programming language."
string2 = "Python can run on different platforms."

# %%
#QUES:1 "+" operator is used to concatenate two strings in python.
print(string1+" "+string2)
# Out:
# Python is a programming language. Python can run on different platforms.

# %%
#QUES:2 #"+" operator is used to concatenate two strings in python.
         #"JOIN" operator is used to combine list and tuples also into a string.
        # examples of both are here:
string3= ["python", "java","C","c++"]
string4= ["easy", "clear","software"]
print(string3+string4)
print(string1+" "+string2)
print("".join(string3+string4))
# Out:
# ['python', 'java', 'C', 'c++', 'easy', 'clear', 'software']
# Python is a programming language. Python can run on different platforms.
# pythonjavaCc++easyclearsoftware

# %%
#QUES 3: By indexing we can access individual character in a string
print(string1[0:6:1])
# Out:
# Python

# %%
#QUES:4 len() method is used to find the length of a string
print(len(string1))
# Out:
# 33

# %%
#QUES:5
print(string1.upper())
# Out:
# PYTHON IS A PROGRAMMING LANGUAGE.

# %%
#QUES:6
print(string1.lower())
# Out:
# python is a programming language.

# %%
#QUES:7
string5= (string1.replace("Python","java"))
print(string5)
# Out:
# java is a programming language.

# %%
#QUES:8
string1.split("P")
# Out:
# ['', 'ython is a programming language.']

# %%
#QUES:9
print(string1.startswith("Python"))
print(string1.startswith("python"))
# Out:
# True
# False

# %%
#QUES:10
print(string1.endswith("language"))
print(string1.endswith("language."))
# Out:
# False
# True

# %%
#QUES:11
string_2 = "    This is a class    "
string_2.strip()
# Out:
# 'This is a class'

# %%
#QUES:12
string6 = "Python is a programming Python language."
print(string6.rindex("Python"))
# Out:
# 0

# %%
#QUES:13
string6 = "Python is a programming Python language."
print(string6.count("Python"))
# Out:
# 2

# %%
#QUES:14
string1.isalpha()
# Out:
# False

# %%
#QUES:15
print(string1.isdigit())
# Out:
# False

# %%
#QUES:16
string7 = "naman"
string8=(string7[::-1])
if (string7 == string8):
    print(f"{string7} is a palindrome")
else:
    print("Not")
# Out:
# naman is a palindrome

# %%
#QUES:17
string9 = "reverse"
print(string9[::-1])
# Out:
# esrever

# %%
#QUES:18 
print (f"{string1} is a language.")
print ("{} is a language.".format(string1))
print ("%s is a language."%(string1))
# Out:
# Python is a programming language. is a language.
# Python is a programming language. is a language.
# Python is a programming language. is a language.

# %%
#QUES: 19
print(string2[1:6:1])
# Out:
# ython

# %%
#QUES: 20
print(string2.replace("can","pan"))
# Out:
# Python pan run on different platforms.
