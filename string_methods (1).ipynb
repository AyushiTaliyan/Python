# %%
string1 = 'Python Learning'

# %%
string2 = "Python Learning"

# %%
string3 = '''Python Learning'''

# %%
string4 ="""Python Learning"""

# %% [markdown]
# #len(string)

# %%
print(len(string3))
# Out:
# 15

# %%
string5 = "Python provides a set of built-in methods"
print(len(string5))
# Out:
# 41

# %%
print(string1[0])
print(string1[1])
print(string1[2])
print(string1[3])
print(string1[4])
print(string1[5])
print(string1[6])
print(string1[7])
# Out:
# P
# y
# t
# h
# o
# n
#
# L

# %%
print(string1[-1])
print(string1[-2])
print(string1[-3])
print(string1[-4])
print(string1[-5])
print(string1[-6])
print(string1[-7])
print(string1[-8])
# Out:
# g
# n
# i
# n
# r
# a
# e
# L

# %%
print(string1[::])
# Out:
# Python Learning

# %%
print(string5[0:len(string5):1])
# Out:
# Python provides a set of built-in methods

# %%
print(string5[5:21:1])
# Out:
# n provides a set

# %%
print(string5[0:40:2])
# Out:
# Pto rvdsasto ul-nmto

# %%
print(string1[-1::])
# Out:
# g

# %%
print(string5[-30:-1:])
# Out:
# ides a set of built-in method

# %%
print(string5[-len(string5):-1:])
# Out:
# Python provides a set of built-in method

# %%
#reverse string 
print(string5[::-1])
# Out:
# sdohtem ni-tliub fo tes a sedivorp nohtyP

# %%
string5.replace("Python","java")
# Out:
# 'java provides a set of built-in methods'

# %%
string6 = "python is a popular, high level programming language. Python is used across wide range of industries. python is dynamicallhy type-checked and garbage collected."

# %%
string6.replace("Python","java")
# Out:
# 'python is a popular, high level programming language. java is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.'

# %%
string6.replace("Python","Java",2)
# Out:
# 'python is a popular, high level programming language. Java is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.'

# %%
string6.capitalize()
# Out:
# 'Python is a popular, high level programming language. python is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.'

# %%
string6.casefold()
# Out:
# 'python is a popular, high level programming language. python is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.'

# %%
string5.upper()
# Out:
# 'PYTHON PROVIDES A SET OF BUILT-IN METHODS'

# %%
string5.lower()
# Out:
# 'python provides a set of built-in methods'

# %%
string5.count("p")
# Out:
# 1

# %%
string6.count("p")
# Out:
# 6

# %%
string5.title()
# Out:
# 'Python Provides A Set Of Built-In Methods'

# %%
string6.title()
# Out:
# 'Python Is A Popular, High Level Programming Language. Python Is Used Across Wide Range Of Industries. Python Is Dynamicallhy Type-Checked And Garbage Collected.'

# %%
string5.swapcase()
# Out:
# 'pYTHON PROVIDES A SET OF BUILT-IN METHODS'

# %%
string5.casefold()
# Out:
# 'python provides a set of built-in methods'

# %%
string6.find("is")
# Out:
# 7

# %%
#gives -1 if sub string not found
string6.find("ik")
# Out:
# -1

# %%
#finds first occurence of sub string
string6.find("and")
# Out:
# 138

# %%
#finds last occurence of sub string
string6.rfind("is")
# Out:
# 109

# %%
string5.index("of")
# Out:
# 22

# %%
string5.index("on")
# Out:
# 4

# %%
string5.startswith(":p")
# Out:
# False

# %%
string5.startswith("P")
# Out:
# True

# %%
string5.endswith("P")
# Out:
# False

# %%
string5.endswith("s")
# Out:
# True

# %%
string5.split("b")
# Out:
# ['Python provides a set of ', 'uilt-in methods']

# %%
string6.center(4)
# Out:
# 'python is a popular, high level programming language. Python is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.'

# %%
string6.encode()
# Out:
# b'python is a popular, high level programming language. Python is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.'

# %%
string5.find("set")
# Out:
# 18

# %%
string5.find("and")
# Out:
# -1

# %%
string5.index("set")
# Out:
# 18

# %%
string5.isalnum()
# Out:
# False

# %%
string5.isalpha()
# Out:
# False

# %%
string5.isascii()
# Out:
# True

# %%
string5.isdecimal()
# Out:
# False

# %%
string5.isdigit()
# Out:
# False

# %%
string5.isidentifier()
# Out:
# False

# %%
string5.islower()
# Out:
# False

# %%
string5.isupper()
# Out:
# False

# %%
string5.isnumeric()
# Out:
# False

# %%
string5.isprintable()
# Out:
# True

# %%
string5.isspace()
# Out:
# False

# %%
string5.istitle()
# Out:
# False

# %%
string7="Python is a set of inbuilt-methods.Python is a language"
string7.rfind("Python")
# Out:
# 35

# %%
string7.rindex("is")
# Out:
# 42

# %%
#split string at line break and returns a list.
string6.splitlines()
# Out:
# ['python is a popular, high level programming language. Python is used across wide range of industries. python is dynamicallhy type-checked and garbage collected.']

# %%
string7.swapcase()
# Out:
# 'pYTHON IS A SET OF INBUILT-METHODS.pYTHON IS A LANGUAGE'

# %%
string7.title()
# Out:
# 'Python Is A Set Of Inbuilt-Methods.Python Is A Language'

# %%
string7.zfill(7)
# Out:
# 'Python is a set of inbuilt-methods.Python is a language'

# %%
string7.encode()
# Out:
# b'Python is a set of inbuilt-methods.Python is a language'

# %%
string7.center("Python")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 string7.center("Python")
#
# TypeError: 'str' object cannot be interpreted as an integer
